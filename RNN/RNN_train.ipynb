# %%
#import data

# -*- coding: utf-8 -*-

#import data

import pandas as pd
import numpy as np
import torch.onnx
import os

import torch
import torch.nn as nn
# import torch.nn.functional as F

import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
from torchvision import datasets, transforms

# %%
# 파일이 위치한 디렉토리 경로
directory_path = r'C:\Users\kyos1\Desktop\Neural Network data\Pytorch_train_data'

# %%
all_x_data = []
all_y_data = []

for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)
        # Pandas를 이용해 파일 읽기
        data = pd.read_csv(file_path, sep=",", header=0, dtype=float)
        x_data = torch.tensor(data.iloc[:, [0,2,3,4,5]].values, dtype=torch.float32)
        y_data = torch.tensor(data.iloc[:, 1:2].values, dtype=torch.float32)
        
        # 전체 데이터 리스트에 추가
        all_x_data.append(x_data)
        all_y_data.append(y_data)
        
# 리스트에 저장된 모든 데이터를 하나의 텐서로 결합
all_x_data = torch.cat(all_x_data, dim=0)
all_y_data = torch.cat(all_y_data, dim=0)

# 전체 데이터에 대한 평균과 분산 계산
mean_x = torch.mean(all_x_data, dim=0)
std_x = torch.std(all_x_data, dim=0)

Max_Vy = max(abs(all_y_data))

# %%
x_data = (all_x_data - mean_x) / std_x  # mean과 std는 훈련 데이터셋에서 계산된 값 사용
y_data = all_y_data/float(Max_Vy)

# 배치사이즈 설정
batch_size = 512

# %%
class My_dataset(Dataset):
    def __init__(self, x_data, y_data, transform=None):  #데이터 셋 선처리 해주는 부분
        self.x_data = x_data
        self.y_data = y_data
        self.transform = transform
        self.len = self.y_data.shape[0]

    def __getitem__(self, index):  # 데이터 셋 한 개의 데이터를 가져오는 함수 정의하는 부분

        if isinstance(index, slice):
            # 슬라이스 처리
            start_index = index.start
            end_index = index.stop
        else:
            # 단일 인덱스 처리
            start_index = index
            end_index = start_index + batch_size

        end_index = min(end_index, self.len)
        x = self.x_data[start_index:end_index]
        y = self.y_data[start_index:end_index]

        if self.transform:
            x, y = self.transform((x, y))
            sample = x, y
        return sample

    def __len__(self):  # 데이터 셋의 길이 적어 주는 부분
        return self.len - batch_size + 1


class ToTensor:
    def __call__(self, sample):
        x, y = sample
        x = torch.FloatTensor(x)
        y = torch.FloatTensor(y)
        return x, y


# 데이터 로드
trans = transforms.Compose([ToTensor()])

train_data = My_dataset(x_data, y_data, transform=trans)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=False)

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(6, 64)
        self.fc2 = torch.nn.Linear(64, 64)
        self.fc3 = torch.nn.Linear(64, 1)
        # self.fc4 = torch.nn.Linear(1, 1)
        self.ln1 = torch.nn.LayerNorm(64)
        self.ln2 = torch.nn.LayerNorm(64)
        # self.ln3 = torch.nn.LayerNorm(32)
        self.dropout = torch.nn.Dropout()
        self.gelu = torch.nn.GELU()

    def forward(self, x):
        x = self.gelu(self.ln1(self.fc1(x)))
        x = self.dropout(x)
        x = self.gelu(self.ln2(self.fc2(x)))
        x = self.dropout(x)
        # x = self.gelu(self.ln3(self.fc3(x)))
        # x = self.dropout(x)
        x = torch.tanh(self.fc3(x))
        return x

# model = Net().to(device)
model = Net()
Loss = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.00005)

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.99)

# %%
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(total_params)
# Out:
# 4929

# %%
losses = []

# 훈련 루프
num_epochs = 600
num_data = len(x_data)

batch_predictions = torch.zeros(batch_size, 1)

min_loss = 50
training_epoch = 0
try:
    for epoch in range(num_epochs):
        losses = []
        epoch_losses = []
        average_losses = []
        prev_targets = torch.zeros(1,1)
    
        for i in range(0, num_data - batch_size + 1, batch_size):
            inputs, targets = train_data[i:i + batch_size]
            
            optimizer.zero_grad()
            
            batch_prediction_list = []
            current_batch_size = inputs.size(0)
            prev_predictions = torch.zeros(1, 1)
            prev_targets = prev_targets
    
            for j in range(batch_size):
                zero_predictions = torch.zeros(1, 1)
                # bank_err_1 = inputs[j, 1] - prev_predictions
    
    
                if i == 0 and j == 0:
                    bank_err_1 = inputs[j, 1] - zero_predictions
                    step_inputs = torch.cat([inputs[j].unsqueeze(0), zero_predictions], dim=1)
    
                elif i >= 1 and j == 0:
                    # bank_err_1 = inputs[j, 0] - prev_predictions
                    step_inputs = torch.cat([inputs[j].unsqueeze(0), prev_targets], dim=1)
    
                else:
                    step_inputs = torch.cat([inputs[j].unsqueeze(0), prev_targets], dim=1)
                    # print("step_inputs:",step_inputs.size())
    
                step_outputs = model(step_inputs)
                prev_targets = targets[j-1].unsqueeze(0)
                
                prev_predictions = step_outputs
    
    
                batch_prediction_list.append(step_outputs.squeeze())
    
            batch_predictions = torch.stack(batch_prediction_list).view(-1, 1)
    
            loss = Loss(batch_predictions, targets)
    
            epoch_losses.append(loss.item())
    
            # 역전파 및 최적화
            
            loss.backward()
            optimizer.step()
    
        average_losses = np.mean(epoch_losses)
        losses.append(average_losses)
    
        if average_losses < min_loss:
            min_loss = average_losses
            model.eval()  # 모델 평가 모드로 전환
            x_dummy = torch.randn(1, 6)
            traced_model = torch.jit.trace(model, x_dummy)
            torch.jit.save(traced_model, r'C:\Users\kyos1\Desktop\Neural Network data\RNN_model_1.pt')

        if epoch in [100,200,300,400]:
            model.eval()  # 모델을 평가 모드로 설정
            x_dummy = torch.randn(1, 6)
            traced_model = torch.jit.trace(model, x_dummy)
            torch.jit.save(traced_model, rf'C:\Users\kyos1\Desktop\Neural Network data\RNN_model_{epoch}.pt')

        # Scheduler 업데이트
        scheduler.step()
        training_epoch = epoch
        # 진행 상황 출력 (선택적)
        print(f"Epoch {epoch}, average_losses: {average_losses}")        

except KeyboardInterrupt:
    print("Training interrupted. Saving the model.")
    model.eval()  # 모델을 평가 모드로 설정
    x_dummy = torch.randn(1, 6)
    traced_model = torch.jit.trace(model, x_dummy)
    # 트레이싱된 모델 저장
    torch.jit.save(traced_model, r'C:\Users\kyos1\Desktop\Neural Network data\RNN_model_2.pt')

# 모델 저장
model.eval()  # 모델을 평가 모드로 설정
x_dummy = torch.randn(1, 6)
traced_model = torch.jit.trace(model, x_dummy)

# 트레이싱된 모델 저장
torch.jit.save(traced_model, r'C:\Users\kyos1\Desktop\Neural Network data\RNN_model_3.pt')
print("Traced model saved.")
# Out:
# Epoch 0, average_losses: 0.08148891452919034
# Epoch 1, average_losses: 0.004897725487813552
# Epoch 2, average_losses: 0.003287905302572386
# Epoch 3, average_losses: 0.0024483539912869353
# Epoch 4, average_losses: 0.0019274803502219798
# Epoch 5, average_losses: 0.0015882437601559265
# Epoch 6, average_losses: 0.0013467082715841472
# Epoch 7, average_losses: 0.0011599401818950675
# Epoch 8, average_losses: 0.0010078518665485557
# Epoch 9, average_losses: 0.0008802753818797689
# Epoch 10, average_losses: 0.0007713463514231561
# Epoch 11, average_losses: 0.000677424780517279
# Epoch 12, average_losses: 0.0005962121961232804
# Epoch 13, average_losses: 0.0005262635245970374
# Epoch 14, average_losses: 0.0004665801535210288
# Epoch 15, average_losses: 0.00041625670402883024
# Epoch 16, average_losses: 0.00037429386250176536
# Epoch 17, average_losses: 0.00033953185329825347
# Epoch 18, average_losses: 0.0003106864359270891
# Epoch 19, average_losses: 0.0002864749008725031
# Epoch 20, average_losses: 0.00026579767453661
# Epoch 21, average_losses: 0.00024786081713768106
# Epoch 22, average_losses: 0.00023216625116968798
# Epoch 23, average_losses: 0.00021840592557804056
# Epoch 24, average_losses: 0.00020636204848696092
# Epoch 25, average_losses: 0.00019584166278436294
# Epoch 26, average_losses: 0.00018665080123408937
# Epoch 27, average_losses: 0.00017859379910680005
# Epoch 28, average_losses: 0.00017148393480992502
# Epoch 29, average_losses: 0.00016516163463861362
# Epoch 30, average_losses: 0.0001594942793952428
# Epoch 31, average_losses: 0.0001543865409648253
# Epoch 32, average_losses: 0.00014976833647618632
# Epoch 33, average_losses: 0.00014558884155656628
# Epoch 34, average_losses: 0.00014180848908782698
# Epoch 35, average_losses: 0.0001383949482217705
# Epoch 36, average_losses: 0.00013531435672228006
# Epoch 37, average_losses: 0.00013252932795855004
# Epoch 38, average_losses: 0.00013000501975030226
# Epoch 39, average_losses: 0.00012770254728339375
# Epoch 40, average_losses: 0.00012558315907774479
# Epoch 41, average_losses: 0.00012360489141482342
# Epoch 42, average_losses: 0.00012173409523818597
# Epoch 43, average_losses: 0.00011993353765587123
# Epoch 44, average_losses: 0.00011818247980312769
# Epoch 45, average_losses: 0.00011645864484468321
# Epoch 46, average_losses: 0.00011475272574363557
# Epoch 47, average_losses: 0.00011305629089667277
# Epoch 48, average_losses: 0.00011136791385016456
# Epoch 49, average_losses: 0.00010969120319018925
# Epoch 50, average_losses: 0.00010784327030973253
# Epoch 51, average_losses: 0.00010600411335872196
# Epoch 52, average_losses: 0.00010414011652274519
# Epoch 53, average_losses: 0.00010262672008620403
# Epoch 54, average_losses: 0.0001011589123904474
# Epoch 55, average_losses: 9.975571697984432e-05
# Epoch 56, average_losses: 9.838556689186696e-05
# Epoch 57, average_losses: 9.706933778782995e-05
# Epoch 58, average_losses: 9.58133065213427e-05
# Epoch 59, average_losses: 9.462467059433146e-05
# Epoch 60, average_losses: 9.350750994866864e-05
# Epoch 61, average_losses: 9.24609042960904e-05
# Epoch 62, average_losses: 9.148304667552806e-05
# Epoch 63, average_losses: 9.057102011598438e-05
# Epoch 64, average_losses: 8.972054042688422e-05
# Epoch 65, average_losses: 8.892866179501331e-05
# Epoch 66, average_losses: 8.819072662069683e-05
# Epoch 67, average_losses: 8.750385571816236e-05
# Epoch 68, average_losses: 8.686566249012044e-05
# Epoch 69, average_losses: 8.625212486977569e-05
# Epoch 70, average_losses: 8.57424171649387e-05
# Epoch 71, average_losses: 8.52353993746767e-05
# Epoch 72, average_losses: 8.482208956379241e-05
# Epoch 73, average_losses: 8.445044455691138e-05
# Epoch 74, average_losses: 8.414537029025002e-05
# Epoch 75, average_losses: 8.38974422924152e-05
# Epoch 76, average_losses: 8.373228516521682e-05
# Epoch 77, average_losses: 8.36430325098798e-05
# Epoch 78, average_losses: 8.362403554201592e-05
# Epoch 79, average_losses: 8.36735093188883e-05
# Epoch 80, average_losses: 8.379408743327503e-05
# Epoch 81, average_losses: 8.399613495812981e-05
# Epoch 82, average_losses: 8.428224946275055e-05
# Epoch 83, average_losses: 8.462837817098582e-05
# Epoch 84, average_losses: 8.500615744089694e-05
# Epoch 85, average_losses: 8.540885324103275e-05
# Epoch 86, average_losses: 8.578460116897237e-05
# Epoch 87, average_losses: 8.613140005068357e-05
# Epoch 88, average_losses: 8.643837955734103e-05
# Epoch 89, average_losses: 8.667417827168453e-05
# Epoch 90, average_losses: 8.688218413921918e-05
# Epoch 91, average_losses: 8.706118550863346e-05
# Epoch 92, average_losses: 8.728401924118396e-05
# Epoch 93, average_losses: 8.753307258998307e-05
# Epoch 94, average_losses: 8.78614695091742e-05
# Epoch 95, average_losses: 8.833161729211604e-05
# Epoch 96, average_losses: 8.894736695176963e-05
# Epoch 97, average_losses: 8.98174608081557e-05
# Epoch 98, average_losses: 9.092834987126586e-05
# Epoch 99, average_losses: 9.219925384273023e-05
# Epoch 100, average_losses: 9.233202846082671e-05
# Epoch 101, average_losses: 9.33069521734604e-05
# Epoch 102, average_losses: 9.292903777537397e-05
# Epoch 103, average_losses: 9.214053993486339e-05
# Epoch 104, average_losses: 9.141307153293062e-05
# Epoch 105, average_losses: 9.092964908658735e-05
# Epoch 106, average_losses: 9.065315068309086e-05
# Epoch 107, average_losses: 9.047773720233047e-05
# Epoch 108, average_losses: 9.032155065249432e-05
# Epoch 109, average_losses: 9.016454709688011e-05
# Epoch 110, average_losses: 9.00504428139303e-05
# Epoch 111, average_losses: 8.99510332622894e-05
# Epoch 112, average_losses: 8.989274357297878e-05
# Epoch 113, average_losses: 8.983252083399909e-05
# Epoch 114, average_losses: 8.981644308866688e-05
# Epoch 115, average_losses: 8.983134563657265e-05
# Epoch 116, average_losses: 8.985927821894995e-05
# Epoch 117, average_losses: 8.9847424901296e-05
# Epoch 118, average_losses: 8.991935727408418e-05
# Epoch 119, average_losses: 8.995714153276341e-05
# Epoch 120, average_losses: 8.999813894687952e-05
# Epoch 121, average_losses: 9.002155500424766e-05
# Epoch 122, average_losses: 9.004590979309475e-05
# Epoch 123, average_losses: 9.004952677086669e-05
# Epoch 124, average_losses: 9.010843099156986e-05
# Epoch 125, average_losses: 9.009596166004699e-05
# Epoch 126, average_losses: 9.011241458852858e-05
# Epoch 127, average_losses: 9.010692099148882e-05
# Epoch 128, average_losses: 9.015551365176661e-05
# Epoch 129, average_losses: 9.018516338180822e-05
# Epoch 130, average_losses: 9.017796264529085e-05
# Epoch 131, average_losses: 9.01722758782639e-05
# Epoch 132, average_losses: 9.018235877406636e-05
# Epoch 133, average_losses: 9.017263211128866e-05
# Epoch 134, average_losses: 9.015203216784036e-05
# Epoch 135, average_losses: 9.011524421941216e-05
# Epoch 136, average_losses: 9.009352360729227e-05
# Epoch 137, average_losses: 9.002565103615137e-05
# Epoch 138, average_losses: 8.995631595526528e-05
# Epoch 139, average_losses: 8.99109953923685e-05
# Epoch 140, average_losses: 8.982940343551438e-05
# Epoch 141, average_losses: 8.970868588301742e-05
# Epoch 142, average_losses: 8.957542222935231e-05
# Epoch 143, average_losses: 8.943041145598459e-05
# Epoch 144, average_losses: 8.928408088837279e-05
# Epoch 145, average_losses: 8.91316556975225e-05
# Epoch 146, average_losses: 8.895499635427234e-05
# Epoch 147, average_losses: 8.8766237658199e-05
# Epoch 148, average_losses: 8.859111724097388e-05
# Epoch 149, average_losses: 8.840276543330273e-05
# Epoch 150, average_losses: 8.723893785854135e-05
# Epoch 151, average_losses: 8.661291167781575e-05
# Epoch 152, average_losses: 8.656488001526989e-05
# Epoch 153, average_losses: 8.646397429107738e-05
# Epoch 154, average_losses: 8.629065412044249e-05
# Epoch 155, average_losses: 8.611354586237747e-05
# Epoch 156, average_losses: 8.591054019635681e-05
# Epoch 157, average_losses: 8.564476407066062e-05
# Epoch 158, average_losses: 8.534664351961564e-05
# Epoch 159, average_losses: 8.508598721003663e-05
# Epoch 160, average_losses: 8.484540513697592e-05
# Epoch 161, average_losses: 8.456806149324086e-05
# Epoch 162, average_losses: 8.430731504497945e-05
# Epoch 163, average_losses: 8.404936711298539e-05
# Epoch 164, average_losses: 8.379043587785204e-05
# Epoch 165, average_losses: 8.35478710838716e-05
# Epoch 166, average_losses: 8.331597018669152e-05
# Epoch 167, average_losses: 8.306568442415429e-05
# Epoch 168, average_losses: 8.281985142596514e-05
# Epoch 169, average_losses: 8.256010622945349e-05
# Epoch 170, average_losses: 8.230958166971986e-05
# Epoch 171, average_losses: 8.207793809908574e-05
# Epoch 172, average_losses: 8.187258946370147e-05
# Epoch 173, average_losses: 8.165714409161036e-05
# Epoch 174, average_losses: 8.144272133583453e-05
# Epoch 175, average_losses: 8.124685316916464e-05
# Epoch 176, average_losses: 8.1013242376203e-05
# Epoch 177, average_losses: 8.082042025254101e-05
# Epoch 178, average_losses: 8.06239305773167e-05
# Epoch 179, average_losses: 8.04278374166375e-05
# Epoch 180, average_losses: 8.022853046788763e-05
# Epoch 181, average_losses: 8.002654722665338e-05
# Epoch 182, average_losses: 7.983976434923747e-05
# Epoch 183, average_losses: 7.964312029076502e-05
# Epoch 184, average_losses: 7.943137166046868e-05
# Epoch 185, average_losses: 7.922007102345507e-05
# Epoch 186, average_losses: 7.90254922278965e-05
# Epoch 187, average_losses: 7.88118980044066e-05
# Epoch 188, average_losses: 7.861868268665764e-05
# Epoch 189, average_losses: 7.838595972958395e-05
# Epoch 190, average_losses: 7.820484134005229e-05
# Epoch 191, average_losses: 7.801356667026566e-05
# Epoch 192, average_losses: 7.781621847537762e-05
# Epoch 193, average_losses: 7.76115355807526e-05
# Epoch 194, average_losses: 7.741931172457793e-05
# Epoch 195, average_losses: 7.718392430112598e-05
# Epoch 196, average_losses: 7.698933504664584e-05
# Epoch 197, average_losses: 7.684768765450238e-05
# Epoch 198, average_losses: 7.665327327819849e-05
# Epoch 199, average_losses: 7.649366619181606e-05
# Epoch 200, average_losses: 7.565237902781518e-05
# Epoch 201, average_losses: 7.507963496931659e-05
# Epoch 202, average_losses: 7.512121164435324e-05
# Epoch 203, average_losses: 7.504061052580202e-05
# Epoch 204, average_losses: 7.495168602337585e-05
# Epoch 205, average_losses: 7.482425320310593e-05
# Epoch 206, average_losses: 7.469234112758226e-05
# Epoch 207, average_losses: 7.453472006519031e-05
# Epoch 208, average_losses: 7.441198928250635e-05
# Epoch 209, average_losses: 7.428665896762087e-05
# Epoch 210, average_losses: 7.418858400663285e-05
# Epoch 211, average_losses: 7.410240274914351e-05
# Epoch 212, average_losses: 7.399836708908183e-05
# Epoch 213, average_losses: 7.384408283114146e-05
# Epoch 214, average_losses: 7.374664094507298e-05
# Epoch 215, average_losses: 7.369450394970258e-05
# Epoch 216, average_losses: 7.362287468715615e-05
# Epoch 217, average_losses: 7.355419071406205e-05
# Epoch 218, average_losses: 7.349836764098975e-05
# Epoch 219, average_losses: 7.339717817772266e-05
# Epoch 220, average_losses: 7.331628393892649e-05
# Epoch 221, average_losses: 7.327178293267293e-05
# Epoch 222, average_losses: 7.318460687415876e-05
# Epoch 223, average_losses: 7.314885072366237e-05
# Epoch 224, average_losses: 7.305807382983724e-05
# Epoch 225, average_losses: 7.300502123625312e-05
# Epoch 226, average_losses: 7.297089165951868e-05
# Epoch 227, average_losses: 7.290897878165731e-05
# Epoch 228, average_losses: 7.284945731792986e-05
# Epoch 229, average_losses: 7.280823527333483e-05
# Epoch 230, average_losses: 7.275492695070544e-05
# Epoch 231, average_losses: 7.267416841413625e-05
# Epoch 232, average_losses: 7.26503739002403e-05
# Epoch 233, average_losses: 7.257897284088197e-05
# Epoch 234, average_losses: 7.251539604620869e-05
# Epoch 235, average_losses: 7.246883525193184e-05
# Epoch 236, average_losses: 7.238312609147483e-05
# Epoch 237, average_losses: 7.229894075220834e-05
# Epoch 238, average_losses: 7.226408993280048e-05
# Epoch 239, average_losses: 7.21739593660352e-05
# Epoch 240, average_losses: 7.210304450462204e-05
# Epoch 241, average_losses: 7.200196977999653e-05
# Epoch 242, average_losses: 7.191732122839098e-05
# Epoch 243, average_losses: 7.185601565946426e-05
# Epoch 244, average_losses: 7.17790420875484e-05
# Epoch 245, average_losses: 7.169340075078628e-05
# Epoch 246, average_losses: 7.161871262028666e-05
# Epoch 247, average_losses: 7.154968142993525e-05
# Epoch 248, average_losses: 7.148124199134412e-05
# Epoch 249, average_losses: 7.142433707191659e-05
# Epoch 250, average_losses: 7.071432977307482e-05
# Epoch 251, average_losses: 7.013329874553165e-05
# Epoch 252, average_losses: 7.023904232429392e-05
# Epoch 253, average_losses: 7.018903146217781e-05
# Epoch 254, average_losses: 7.014925214020075e-05
# Epoch 255, average_losses: 7.01092685400962e-05
# Epoch 256, average_losses: 7.010335932297012e-05
# Training interrupted. Saving the model.
# Traced model saved.
